# %%
x1= int(input("enter X1 value"))
x2= int(input("enter X2 value"))
y1= int(input("enter y1 value"))
y2= int(input("enter y2 value"))
result=(((x2-x1)**2 + (y2-y1)**2)**0.5)
print("the distance between two points",(x1,x2),"and",(y1,y2),"=",result)
# Out:
# enter X1 value 5
# enter X2 value 6
# enter y1 value 83
# enter y2 value 90
# the distance between two points (5, 6) and (83, 90) = 7.0710678118654755

# %%
num1=int(input("Enter the first Number"))
num2=int(input("Enter the Second Number"))
sum=num1+num2
print("The Sum of Two numbers is", sum)
# Out:
# Enter the first Number 80
# Enter the Second Number 56
# The Sum of Two numbers is 136

# %%
import sys
sys.argv = ['D:/,All_language_Coding/COLLEGE/add.py', '10', '20']

num1 = int(sys.argv[1])
num2 = int(sys.argv[2])

print("Sum =", num1 + num2)
# Out:
# Sum = 30
