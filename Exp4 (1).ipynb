# %%
#Exp 4.1
my_list = [10,20,30,40]
my_tuple =(10,20,30,40)
print("List elements: ")
for item in my_list:
    print(item)
print("Tuple elements: ")
for tuple in my_tuple:
    print(tuple)
# Out:
# List elements:
# 10
# 20
# 30
# 40
# Tuple elements:
# 10
# 20
# 30
# 40

# %%
#Exp 4.2
num = int(input("Enter a number: "))
while num>=0:
    print(num)
    num -=1
# Out:
# Enter a number:  6
# 6
# 5
# 4
# 3
# 2
# 1
# 0
