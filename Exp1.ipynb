# %%
# set datatype 
# a={10,20,30,30,30}
a={10,20,30,30,30}
print(a)
print(type(a))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
# Q1. wap to add two number input should be taken from user datatype <int,float>
a=int(input("ENETER THE FIRST NUMBER: "))
b=float(input("ENETER THE SECOND NUMBER: "))

print("TYPE OF 1st NUMBER: ",type(a))
print("TYPE OF 2ND NUMBER: ",type(b))
# Out:
# ENETER THE FIRST NUMBER:  shivi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Q1. wap to add two number input should be taken from user datatype <int,float>
# ----> 2 a=int(input("ENETER THE FIRST NUMBER: "))
#       3 b=float(input("ENETER THE SECOND NUMBER: "))
#       5 print("TYPE OF 1st NUMBER: ",type(a))
#
# ValueError: invalid literal for int() with base 10: 'shivi'

# %%
# CHECK THAT A GIVEN NUMBER IF EVEN OR ODD
a=int(input("ENETER THE NUMBER: "))
if a%2==0:
    print("Even number : ",a)
    
else:
    print("Odd number : ",a)
# Out:
# ENETER THE NUMBER:  5
# Odd number :  5

# %%
# LARGEST AMONG 2 NUMBER
a=int(input("ENETER THE FIRST NUMBER: "))
b=int(input("ENETER THE SECOND NUMBER: "))
if a>b:
    print("Largest number is 1st: ",a)

else:
    print("Largest number is 2nd: ",b)
# Out:
# ENETER THE FIRST NUMBER:  15
# ENETER THE SECOND NUMBER:  168
# Largest number is 2nd:  168

# %%
# check the given number is prime or not
a=int(input("ENETER THE FIRST NUMBER: "))
if a<=1:
    print("Non prime : ",a)

else:
    for i in range (2,a+1):
        if(a%i==0):
            print("Non prime : ",a)
            break

    else:
        print("Prime : ",a)
# Out:
# ENETER THE FIRST NUMBER:  154
# Non prime :  154

# %%
# Find the CI and take the value from the user.

Principal=int(input("ENETER THE Principal Amount: "))
Time=int(input("ENETER THE Time: "))
Rate=int(input("ENETER THE Rate: "))
result=Principal*((1+(Rate/100))**Time)
print("Compound Interest : ",result)
# Out:
# ENETER THE Principal Amount:  20000
# ENETER THE Time:  2
# ENETER THE Rate:  20
# Compound Interest :  28800.0
